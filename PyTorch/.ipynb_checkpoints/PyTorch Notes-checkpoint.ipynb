# %% [markdown]
# # <font color='#c40509'>PyTorch Notes</font>
#
# ### <font color='Blue'>Contents</font>
#
# * PyTorch Fundamentals
#      * Simple array manipulations/creations
#      * Define manual seed
#      * Move tensor from CPU to GPU and back
#      * Tensor manipulations
# * Variables and Gradients
#      * Variable creation
#      *   Compute gradient
# * Neural Networks
#      *   Define simple NN
#      *   NN with optimizer and loss
#      *   NN class based
#      *   NN sequential mixed with class approach
#      *   Convolution Examples
# * Define custom functions
#      *   New style
#      *   Old style
# * Next topics
#      *   Train flag
#      *   Learning Rate Schedule
#      *   Data Loaders
#      *   Use volatile flag during inference
#      *   Weights initialization
#      *   Work with CUDA
#
# # <font color='#c40509'>PyTorch Fundamentals</font>
# ### <font color='#c40509'>Simple array manipulations and creations</font>
# > ![1](p1.png)
#
# ### <font color='#c40509'>Define manual seed</font>
# > ![](p2.png)
#
# ### <font color='#c40509'>Move tensor from CPU to GPU and back</font>
# > ![](p3.png)
# ### <font color='#c40509'>Tensor manipulations</font>
# > ![](p4.png)
# # <font color='#c40509'>Variables and Gradients</font>
#
# ### <font color='#c40509'>Variable creation</font>
# > ![](p5.png)
# ### <font color='#c40509'>Compute gradient</font>
# > ![](p6.png)
# # <font color='#c40509'>Neural Networks</font>
# ### <font color='#c40509'>Define simple NN</font>
#
# Simple network without any optimizer and manually defined loss function
# > ![](p7.png)
#   ![](p8.png)
#
#
# ### <font color='#c40509'>NN with optimizer and loss/font>
#
# Now we will define network with nn module and with already predefined optimizer and loss<
# > ![](p9.png)
# ### <font color='#c40509'>NN class based</font>
# Create NN as class inherited from torch.nn.Module with convolution and linear layers
# > ![](p10.png)
#
#
# ### <font color='#c40509'>NN sequential mixed with class approach</font>
# > ![](p11.png)
#
# ### <font color='#c40509'>Convolution Examples</font>
# Conv2d have such inputs: in_channels, out_channels, kernel_size
# > ![](p12.png)
#
#
# # <font color='#c40509'>Define custom functions</font>
#
# ### <font color='#c40509'>New style</font>
# > ![](p13.png)
#
# ### <font color='#c40509'>Old style</font>
# > ![](p14.png)
#
# # <font color='#c40509'>Next topics</font>
#
# ### <font color='#c40509'>Train flag</font>
# Train flag can be updated with boolean to disable dropout and batch norm learning
# > ![](p15.png)
#
# ### <font color='#c40509'>Learning Rate Schedule</font>
#
# PyTorch have a lot of learning rate schedulers out of the box
# > ![](p16.png)
#
# ### <font color='#c40509'>Data Loaders</font>
# > ![](p17.png)
#   ![](p18.png)
#   ![](p19.png)
#
# ### <font color='#c40509'>Use volatile flag during inference</font>
#
#
# In case of inference it’s better provide volatile flag during variable creation. It can be provided only in case if you exactly sure that there will be no any gradients computing
# > ![](p20.png)
# ### <font color='#c40509'>Weights initialization</font>
#
#
# Weight initializtion in pytorch can be implemented in two ways:
# > ![](p21.png)
# ### <font color='#c40509'>Work with CUDA</font>
# > ![](p22.png)
